# %% [markdown]
# # Part 0: Startup

# %%
import pandas as pd
import numpy as np
from datetime import date, timedelta, datetime
import pytz

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (4.66.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install kaleido
# Out:
# Requirement already satisfied: kaleido in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.18 in /Users/sunshinela/Library/Python/3.9/lib/python/site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from statsmodels) (1.11.1)
# Requirement already satisfied: pandas>=1.0 in /Users/sunshinela/Library/Python/3.9/lib/python/site-packages (from statsmodels) (1.5.1)
# Requirement already satisfied: patsy>=0.5.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /Users/sunshinela/Library/Python/3.9/lib/python/site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/sunshinela/Library/Python/3.9/lib/python/site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/sunshinela/Library/Python/3.9/lib/python/site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/sunshinela/Library/Python/3.9/lib/python/site-packages (from pandas>=1.0->statsmodels) (2022.6)
# Requirement already satisfied: six in /Users/sunshinela/Library/Python/3.9/lib/python/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (5.17.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /Users/sunshinela/Library/Python/3.9/lib/python/site-packages (from plotly) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/sunshinela/Library/Python/3.9/lib/python/site-packages (from packaging->plotly) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Part III Index

# %% [markdown]
# ## proposer reward

# %%
import pandas as pd
reward=pd.read_csv('rewards.csv')
reward['Date']=reward['Date'].astype('datetime64[ns]')
reward.dtypes
reward.columns
# Out:
# Index(['Date', 'Validator_index', 'final_total_count', 'final_total_sum',
#        'proposer_count', 'proposer_sum', 'attest_count', 'attest_sum',
#        'sync_count', 'sync_sum', 'epoch_count'],
#       dtype='object')

# %%
reward.head()
# Out:
#         Date  Validator_index  final_total_count  final_total_sum  \
# 0 2022-09-15                0                162          2317783
# 1 2022-09-15                1                162          2285993
# 2 2022-09-15                2                162          2261322
# 3 2022-09-15                3                162          2314157
# 4 2022-09-15                4                162          2314936
#
#    proposer_count  proposer_sum  attest_count  attest_sum  sync_count  \
# 0               0             0           162     2317783           0
# 1               0             0           162     2285993           0
# 2               0             0           162     2261322           0
# 3               0             0           162     2314157           0
# 4               0             0           162     2314936           0
#
#    sync_sum  epoch_count
# 0         0          162
# 1         0          162
# 2         0          162
# 3         0          162
# 4         0          162

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Sample data, replace with your actual data
df = reward.copy()

# Calculate the mean of proposer_count by Date
attest_count = df.groupby('Date')['attest_count'].sum().reset_index()
attest_count = attest_count[1:-2]
# Create a subplot layout: 2 rows and 1 column
fig = make_subplots(rows=1, cols=2, shared_xaxes=True, vertical_spacing=0.1)

# Add box plot to the top
fig.add_trace(go.Box(y=attest_count['attest_count'], name='Box plot of proposer counts mean'), row=1, col=1)

# Add time series plot to the bottom
fig.add_trace(go.Scatter(x=attest_count['Date'], y=attest_count['attest_count'], mode='lines', name='Attester counts over time'), row=1, col=2)

# Set the font to 'Courier New', title for the figure, and adjust legend position
fig.update_layout(
    font=dict(
        family="Courier New, monospace",
        size=18,
    ),
    title='Daily Mean of Attester Count',
    legend=dict(
        x=0.5,
        y=1.15,
        orientation="h",
        xanchor="center"
    )
)

fig.show()

# %%
# Save the figure with high resolution
fig.write_image("validator_count_attester.png", width=1600, height=900, scale=3)  # The scale parameter can be adjusted for desired resolution.

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Sample data, replace with your actual data
df = reward.copy()

# Calculate the mean of Validator_index by Date
validator_means = df.groupby('Date')['attest_sum'].mean().reset_index()
validator_means = validator_means[1:-2]
# Create a subplot layout: 2 rows and 1 column
fig = make_subplots(rows=1, cols=2, shared_xaxes=True, vertical_spacing=0.1)

# Add box plot to the top
fig.add_trace(go.Box(y=validator_means['attest_sum'], name='Box plot of attester reward means'), row=1, col=1)

# Add time series plot to the bottom
fig.add_trace(go.Scatter(x=validator_means['Date'], y=validator_means['attest_sum'], mode='lines', name='attester reward means over time'), row=1, col=2)

# Set the font to 'Courier New', title for the figure, and adjust legend position
fig.update_layout(
    font=dict(
        family="Courier New, monospace",
        size=18,
    ),
    title='Daily Mean Attester Reward',
    legend=dict(
        x=0.5,
        y=1.15,
        orientation="h",
        xanchor="center"
    )
)

# Update the y-axis label
fig.update_yaxes(title_text="reward (gwei)")

fig.show()

# %%
# Save the figure with high resolution
fig.write_image("attester_reward_mean_proposer.png", width=1600, height=900, scale=3)  # The scale parameter can be adjusted for desired resolution.

# %%
# set the reward to calculate the index
reward_name ='attest_sum'

# %%
df = reward[['Date',reward_name]]
df
# Out:
#                Date  attest_sum
# 0        2022-09-15     2317783
# 1        2022-09-15     2285993
# 2        2022-09-15     2261322
# 3        2022-09-15     2314157
# 4        2022-09-15     2314936
# ...             ...         ...
# 28148852 2022-11-16       13775
# 28148853 2022-11-16       13775
# 28148854 2022-11-16       13775
# 28148855 2022-11-16       13775
# 28148856 2022-11-16       13775
#
# [28148857 rows x 2 columns]

# %%
data =df.copy()
data.columns =['Date','value']

# %%
data =df.copy()
# Drop rows corresponding to the earliest and latest dates
earliest_date = data['Date'].iloc[0]
latest_date = data['Date'].iloc[-1]
data = data[(data['Date'] != earliest_date) & (data['Date'] != latest_date)]
data
data.columns =['Date','value']

# Set negative values in 'value' column to 0
data.loc[data['value'] < 0, 'value'] = 0
data
# Out:
#                Date    value
# 427336   2022-09-16  3211560
# 427337   2022-09-16  3215277
# 427338   2022-09-16  3222556
# 427339   2022-09-16  3183328
# 427340   2022-09-16  3225452
# ...             ...      ...
# 27680439 2022-11-15    69774
# 27680440 2022-11-15    69774
# 27680441 2022-11-15    69774
# 27680442 2022-11-15    56034
# 27680443 2022-11-15    56034
#
# [27253108 rows x 2 columns]

# %%
data.describe()
# Out:
#               value
# count  2.725311e+07
# mean   3.140311e+06
# std    2.345161e+05
# min    0.000000e+00
# 25%    3.126576e+06
# 50%    3.166207e+06
# 75%    3.201505e+06
# max    3.261285e+06

# %%
def index(df):
    df['value'] = df['value'].astype(float)
    df['prop'] = df['value']/df['value'].sum() 
    H = -df['prop']*np.log2(df['prop'])
    E = H.sum()
    V = 2**E
    return V

def HHI(df):
    df['value'] = df['value'].astype(float)
    df['prop'] = df['value']/df['value'].sum()*100
    SQ = df['prop']**2
    V = SQ.sum()
    return V

def gini(df):
    """
    Compute Gini coefficient of a DataFrame with a 'value' column
    """
    # Check if the DataFrame is empty or the 'value' column does not exist
    if df.empty or 'value' not in df.columns:
        return None 
    # Extract the 'value' column and convert it to a sorted list
    values = sorted(df['value'].tolist())
    # Check if the list is empty
    if len(values) == 0:
        return None
    # Compute the cumulative sum of the values
    cum_values = [0] + list(pd.Series(values).cumsum())
    n = len(values)
    # Calculate Gini coefficient using the formula
    numer = sum([(i+1) * values[i] for i in range(n)])
    denom = n * sum(values)
    if denom == 0:
        return None  # Avoid division by zero
    gini = (2 * numer) / denom - (n + 1) / n
    return gini

def nakamoto(df):
    df['value'] = df['value'].astype(float)
    df.sort_values(by=['value'],ascending=False,inplace=True)
    df.reset_index(inplace=True,drop=True)
    df.set_index(keys=df.index.values+1,inplace=True)
    df['prop'] = df['value']/df['value'].sum() 
    df['cumprop'] = df['prop'].cumsum(axis=0)
    try:
        V = df[df['cumprop'] > 0.5].index[0]
        return V
    except:
        return 0

# %%
from datetime import date
start = date(2022,9,16)
end = date(2022,11,15)

# %%
"""
def index_calc(data):

            :param data: dataframe containing transaction value and timestamp of the transaction (block_timestamp)
            :type data: pandas.DataFrame object
            :param start: the start date of calculation 00:00:00 UTC
            :type start: datetime.date object
            :param end: the end date of calculation 23:59:59 UTC
            :type end: datetime.date object
            :param index_type: the metrics used for measuring decentralization, default is our index
            :type index_type: index function

    returns pandas dataframe with decentralization index value and date
"""
from tqdm import tqdm
def index_calc(data,  start, end, index_type = index):
    duration= pd.date_range(start=start, end=end)
    days = np.size(duration)
    IndexValues = pd.DataFrame(np.zeros(days), columns=['val'])
    IndexValues['date'] = duration

    for i in tqdm(range(0, days)):
        start_date = start + timedelta(days=i)
        end_date = start_date + timedelta(days=1)
        IndexValues.loc[i,'val'] = index_type(data[(data['Date'].dt.date >= start_date) & (data['Date'].dt.date < end_date)].copy())
    
    return IndexValues

# %%
#input transaction data and desired date range
#returns index value 1 if specification range exceeds data 
start = date(2022,9,16)
end = date(2022,11,15)
results = index_calc(data,start,end)
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# /Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#   2%|▏         | 1/61 [00:08<08:55,  8.93s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#   3%|▎         | 2/61 [00:17<08:37,  8.78s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#   5%|▍         | 3/61 [00:26<08:26,  8.73s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#   7%|▋         | 4/61 [00:34<08:17,  8.72s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#   8%|▊         | 5/61 [00:43<08:07,  8.71s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  10%|▉         | 6/61 [00:52<07:58,  8.71s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  11%|█▏        | 7/61 [01:01<07:49,  8.69s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  13%|█▎        | 8/61 [01:09<07:39,  8.68s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  15%|█▍        | 9/61 [01:18<07:31,  8.68s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  16%|█▋        | 10/61 [01:27<07:22,  8.68s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  18%|█▊        | 11/61 [01:35<07:13,  8.68s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  20%|█▉        | 12/61 [01:44<07:05,  8.69s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  21%|██▏       | 13/61 [01:53<06:56,  8.68s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  23%|██▎       | 14/61 [02:01<06:47,  8.68s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  25%|██▍       | 15/61 [02:10<06:39,  8.67s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  26%|██▌       | 16/61 [02:19<06:31,  8.69s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  28%|██▊       | 17/61 [02:27<06:21,  8.68s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  30%|██▉       | 18/61 [02:36<06:12,  8.66s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  31%|███       | 19/61 [02:45<06:03,  8.66s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  33%|███▎      | 20/61 [02:53<05:55,  8.67s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  34%|███▍      | 21/61 [03:02<05:46,  8.67s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  36%|███▌      | 22/61 [03:11<05:38,  8.67s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  38%|███▊      | 23/61 [03:19<05:29,  8.66s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  39%|███▉      | 24/61 [03:28<05:20,  8.66s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  41%|████      | 25/61 [03:37<05:12,  8.67s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  43%|████▎     | 26/61 [03:45<05:03,  8.69s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  44%|████▍     | 27/61 [03:54<04:55,  8.69s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  46%|████▌     | 28/61 [04:03<04:46,  8.68s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  48%|████▊     | 29/61 [04:11<04:37,  8.67s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  49%|████▉     | 30/61 [04:20<04:29,  8.68s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  51%|█████     | 31/61 [04:29<04:20,  8.67s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  52%|█████▏    | 32/61 [04:37<04:11,  8.67s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  54%|█████▍    | 33/61 [04:46<04:02,  8.67s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  56%|█████▌    | 34/61 [04:55<03:54,  8.67s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  57%|█████▋    | 35/61 [05:03<03:45,  8.66s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  59%|█████▉    | 36/61 [05:12<03:36,  8.66s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  61%|██████    | 37/61 [05:21<03:27,  8.66s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  62%|██████▏   | 38/61 [05:29<03:19,  8.66s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  64%|██████▍   | 39/61 [05:38<03:10,  8.65s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  66%|██████▌   | 40/61 [05:47<03:01,  8.65s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  67%|██████▋   | 41/61 [05:55<02:53,  8.65s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  69%|██████▉   | 42/61 [06:04<02:44,  8.66s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  70%|███████   | 43/61 [06:13<02:35,  8.66s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  72%|███████▏  | 44/61 [06:21<02:27,  8.66s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  74%|███████▍  | 45/61 [06:30<02:18,  8.66s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  75%|███████▌  | 46/61 [06:39<02:09,  8.66s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  77%|███████▋  | 47/61 [06:47<02:01,  8.66s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  79%|███████▊  | 48/61 [06:56<01:52,  8.66s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  80%|████████  | 49/61 [07:05<01:44,  8.70s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  82%|████████▏ | 50/61 [07:13<01:35,  8.72s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  84%|████████▎ | 51/61 [07:22<01:27,  8.71s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  85%|████████▌ | 52/61 [07:31<01:18,  8.70s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  87%|████████▋ | 53/61 [07:40<01:10,  8.78s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  89%|████████▊ | 54/61 [07:49<01:01,  8.77s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  90%|█████████ | 55/61 [07:57<00:52,  8.83s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  92%|█████████▏| 56/61 [08:06<00:44,  8.83s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  93%|█████████▎| 57/61 [08:15<00:35,  8.83s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  95%|█████████▌| 58/61 [08:24<00:26,  8.81s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  97%|█████████▋| 59/61 [08:33<00:17,  8.78s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
#  98%|█████████▊| 60/61 [08:41<00:08,  8.77s/it]/Users/sunshinela/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log2
#
# 100%|██████████| 61/61 [08:50<00:00,  8.70s/it]

# %%
results
# Out:
#               val       date
# 0   423801.675576 2022-09-16
# 1   425473.286371 2022-09-17
# 2   426177.366972 2022-09-18
# 3   427483.295331 2022-09-19
# 4   428449.229365 2022-09-20
# ..            ...        ...
# 56  462192.161896 2022-11-11
# 57  463322.952980 2022-11-12
# 58  464125.363031 2022-11-13
# 59  464608.924049 2022-11-14
# 60  465499.199941 2022-11-15
#
# [61 rows x 2 columns]

# %%
results.to_csv('ShannonIndex_Attester.csv',index=False)

# %%
#specify alternate index metric: HHI
#returns index value 0 if specification range exceeds data
start = date(2022,9,16)
end = date(2022,11,15)
results_HHI = index_calc(data,start,end,HHI)
results_HHI.to_csv('HHI_Index_Attester.csv',index=False)
# Out:
# 100%|██████████| 61/61 [09:16<00:00,  9.12s/it]

# %%
results_HHI
# Out:
#          val       date
# 0   0.023626 2022-09-16
# 1   0.023520 2022-09-17
# 2   0.023477 2022-09-18
# 3   0.023404 2022-09-19
# 4   0.023352 2022-09-20
# ..       ...        ...
# 56  0.021647 2022-11-11
# 57  0.021593 2022-11-12
# 58  0.021553 2022-11-13
# 59  0.021534 2022-11-14
# 60  0.021493 2022-11-15
#
# [61 rows x 2 columns]

# %%
#specify alternate index metric: gini
#returns index value 0 if specification range exceeds data
start = date(2022,9,16)
end = date(2022,11,15)
results_Gini = index_calc(data,start,end,gini)
results_Gini.to_csv('Gini_Index_Attester.csv',index=False)
# Out:
# 100%|██████████| 61/61 [09:17<00:00,  9.13s/it]

# %%
results_Gini
# Out:
#          val       date
# 0   0.023381 2022-09-16
# 1   0.017082 2022-09-17
# 2   0.015431 2022-09-18
# 3   0.013215 2022-09-19
# 4   0.013128 2022-09-20
# ..       ...        ...
# 56  0.010746 2022-11-11
# 57  0.010266 2022-11-12
# 58  0.009649 2022-11-13
# 59  0.012625 2022-11-14
# 60  0.013250 2022-11-15
#
# [61 rows x 2 columns]

# %%
#specify alternate index metric: nakamoto coefficient
#returns index value 0 if specification range exceeds data
start = date(2022,9,16)
end = date(2022,11,15)
results_nakamoto = index_calc(data,start,end,nakamoto)
results_nakamoto.to_csv("results_nakamoto_Attester.csv")
# Out:
# 100%|██████████| 61/61 [09:08<00:00,  8.99s/it]

# %%
results_nakamoto
# Out:
#          val       date
# 0   208766.0 2022-09-16
# 1   210416.0 2022-09-17
# 2   211156.0 2022-09-18
# 3   211901.0 2022-09-19
# 4   212278.0 2022-09-20
# ..       ...        ...
# 56  229051.0 2022-11-11
# 57  229811.0 2022-11-12
# 58  230230.0 2022-11-13
# 59  230101.0 2022-11-14
# 60  230383.0 2022-11-15
#
# [61 rows x 2 columns]

# %%
# Merge all the dataframes together
import pandas as pd

# Assuming the dataframes results, results_HHI, results_Gini, and results_nakamoto are already defined...

# Rename 'val' columns for each dataframe first
results = results.rename(columns={'val': 'ShannonEntropy'})
results_HHI = results_HHI.rename(columns={'val': 'HHI'})
results_Gini = results_Gini.rename(columns={'val': 'Gini'})  # There was a small inconsistency here, I assumed you want to rename this column 'Gini'
results_nakamoto = results_nakamoto.rename(columns={'val': 'Nakamoto'})

# Now, merge the dataframes on the 'Date' column
merged_df = results.merge(results_HHI, on='date', how='outer') \
    .merge(results_Gini, on='date', how='outer') \
    .merge(results_nakamoto, on='date', how='outer')

print(merged_df)
merged_df.columns
# Out:
#     ShannonEntropy       date       HHI      Gini  Nakamoto
# 0    423801.675576 2022-09-16  0.023626  0.023381  208766.0
# 1    425473.286371 2022-09-17  0.023520  0.017082  210416.0
# 2    426177.366972 2022-09-18  0.023477  0.015431  211156.0
# 3    427483.295331 2022-09-19  0.023404  0.013215  211901.0
# 4    428449.229365 2022-09-20  0.023352  0.013128  212278.0
# ..             ...        ...       ...       ...       ...
# 56   462192.161896 2022-11-11  0.021647  0.010746  229051.0
# 57   463322.952980 2022-11-12  0.021593  0.010266  229811.0
# 58   464125.363031 2022-11-13  0.021553  0.009649  230230.0
# 59   464608.924049 2022-11-14  0.021534  0.012625  230101.0
# 60   465499.199941 2022-11-15  0.021493  0.013250  230383.0
#
# [61 rows x 5 columns]
# Index(['ShannonEntropy', 'date', 'HHI', 'Gini', 'Nakamoto'], dtype='object')

# %%
# Reorder the columns
merged_df = merged_df[['date', 'ShannonEntropy', 'HHI', 'Gini', 'Nakamoto']]
Index4=merged_df
Index4.to_csv("Index4_Attester.csv")
Index4
# Out:
#          date  ShannonEntropy       HHI      Gini  Nakamoto
# 0  2022-09-16   423801.675576  0.023626  0.023381  208766.0
# 1  2022-09-17   425473.286371  0.023520  0.017082  210416.0
# 2  2022-09-18   426177.366972  0.023477  0.015431  211156.0
# 3  2022-09-19   427483.295331  0.023404  0.013215  211901.0
# 4  2022-09-20   428449.229365  0.023352  0.013128  212278.0
# ..        ...             ...       ...       ...       ...
# 56 2022-11-11   462192.161896  0.021647  0.010746  229051.0
# 57 2022-11-12   463322.952980  0.021593  0.010266  229811.0
# 58 2022-11-13   464125.363031  0.021553  0.009649  230230.0
# 59 2022-11-14   464608.924049  0.021534  0.012625  230101.0
# 60 2022-11-15   465499.199941  0.021493  0.013250  230383.0
#
# [61 rows x 5 columns]

# %%
Index4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 0 to 60
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            61 non-null     datetime64[ns]
#  1   ShannonEntropy  61 non-null     float64
#  2   HHI             61 non-null     float64
#  3   Gini            61 non-null     float64
#  4   Nakamoto        61 non-null     float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 2.9 KB

# %%
Index4.describe()
# Out:
#        ShannonEntropy        HHI       Gini       Nakamoto
# count       61.000000  61.000000  61.000000      61.000000
# mean    444638.084722   0.022518   0.011878  220354.704918
# std      11430.930260   0.000578   0.002765    5740.555625
# min     423801.675576   0.021493   0.008716  208766.000000
# 25%     436107.014339   0.022032   0.010061  216377.000000
# 50%     442585.703487   0.022601   0.010870  219617.000000
# 75%     454099.786553   0.022940   0.013128  225239.000000
# max     465499.199941   0.023626   0.023381  230383.000000

# %%
data= pd.read_csv('Index4_Attester.csv')

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

# Sample dataframe (replace with your actual dataframe)
df = data.copy()

# Create a 2x2 subplot layout
fig = make_subplots(rows=2, cols=2, subplot_titles=('ShannonEntropy', 'HHI', 'Gini', 'Nakamoto'))
# Add box plots to each subplot
fig.add_trace(go.Box(y=df['ShannonEntropy'], name='ShannonEntropy'), row=1, col=1)
fig.add_trace(go.Box(y=df['HHI'], name='HHI'), row=1, col=2)
fig.add_trace(go.Box(y=df['Gini'], name='Gini'), row=2, col=1)
fig.add_trace(go.Box(y=df['Nakamoto'], name='Nakamoto'), row=2, col=2)

# Explanation with LaTeX
#explanation = r'Note: In this plot, the symbol $\mu$ represents a factor of $10^{-6}$.'

# Update layout for better aesthetics and add explanation
fig.update_layout(
    title='Boxplots of Metrics: Proposer Rewards',
    showlegend=True,
    font=dict(family="Courier New, monospace")
)

fig.show()

# %%
# Save the figure with high resolution
fig.write_image("index_boxplot_attester.png", height=900, width=1600, scale=2)  # The scale parameter can be adjusted for desired resolution.

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

# Sample dataframe (replace with your actual dataframe)
df = data.copy()

# Create a 4x1 subplot layout
fig = make_subplots(rows=4, cols=1, shared_xaxes=False, subplot_titles=('ShannonEntropy', 'HHI', 'Gini', 'Nakamoto'))

# Add traces for each metric
fig.add_trace(go.Scatter(x=df['date'], y=df['ShannonEntropy'], mode='lines', name='ShannonEntropy'), row=1, col=1)
fig.add_trace(go.Scatter(x=df['date'], y=df['HHI'], mode='lines', name='HHI'), row=2, col=1)
fig.add_trace(go.Scatter(x=df['date'], y=df['Gini'], mode='lines', name='Gini'), row=3, col=1)
fig.add_trace(go.Scatter(x=df['date'], y=df['Nakamoto'], mode='lines', name='Nakamoto'), row=4, col=1)

# LaTeX styled title and subplot titles
fig.update_layout(
    title_text="Time Series of Metrics: Proposer Rewards",
    font=dict(family="Courier New, monospace", size=16, color="#7f7f7f"),
    height=1000,  # Adjusted height
    template="plotly"  # Set the theme to ggplot2
)

# Add LaTeX explanation
# Explanation with LaTeX-style formatting
#explanation = "Note: In this plot, the symbol $\\mu$ represents the metric prefix 'micro-', denoting a factor of $10^{-6}$."

# Show the plot
fig.show()

# %%
# Save the figure with high resolution
fig.write_image("index_timeseries_attester.png", height=900, width=1600, scale=2)  # The scale parameter can be adjusted for desired resolution.

# %%
import pandas as pd
from scipy.stats import shapiro, anderson

# Sample dataframe (replace with your actual dataframe)
df = data.copy()

# Shapiro-Wilk Test
def shapiro_test(data):
    stat, p = shapiro(data)
    print(f'Shapiro-Wilk Test:\nStatistic={stat:.5f}, p={p:.5f}')
    if p > 0.05:
        print('Sample looks Gaussian (fail to reject H0)\n')
    else:
        print('Sample does not look Gaussian (reject H0)\n')

# Anderson-Darling Test
def anderson_test(data):
    result = anderson(data)
    print('Anderson-Darling Test:')
    for i in range(len(result.critical_values)):
        sl, cv = result.significance_level[i], result.critical_values[i]
        if result.statistic < cv:
            print(f'At significance level {sl:.2f}, data looks normal (fail to reject H0)')
        else:
            print(f'At significance level {sl:.2f}, data does not look normal (reject H0)')
    print()

columns = ['ShannonEntropy', 'HHI', 'Gini', 'Nakamoto']

for col in columns:
    print(f"Testing for variable: {col}")
    shapiro_test(df[col])
    anderson_test(df[col])
# Out:
# Testing for variable: ShannonEntropy
# Shapiro-Wilk Test:
# Statistic=0.96171, p=0.05371
# Sample looks Gaussian (fail to reject H0)
#
# Anderson-Darling Test:
# At significance level 15.00, data does not look normal (reject H0)
# At significance level 10.00, data does not look normal (reject H0)
# At significance level 5.00, data looks normal (fail to reject H0)
# At significance level 2.50, data looks normal (fail to reject H0)
# At significance level 1.00, data looks normal (fail to reject H0)
#
# Testing for variable: HHI
# Shapiro-Wilk Test:
# Statistic=0.96521, p=0.08025
# Sample looks Gaussian (fail to reject H0)
#
# Anderson-Darling Test:
# At significance level 15.00, data does not look normal (reject H0)
# At significance level 10.00, data looks normal (fail to reject H0)
# At significance level 5.00, data looks normal (fail to reject H0)
# At significance level 2.50, data looks normal (fail to reject H0)
# At significance level 1.00, data looks normal (fail to reject H0)
#
# Testing for variable: Gini
# Shapiro-Wilk Test:
# Statistic=0.84308, p=0.00000
# Sample does not look Gaussian (reject H0)
#
# Anderson-Darling Test:
# At significance level 15.00, data does not look normal (reject H0)
# At significance level 10.00, data does not look normal (reject H0)
# At significance level 5.00, data does not look normal (reject H0)
# At significance level 2.50, data does not look normal (reject H0)
# At significance level 1.00, data does not look normal (reject H0)
#
# Testing for variable: Nakamoto
# Shapiro-Wilk Test:
# Statistic=0.96454, p=0.07432
# Sample looks Gaussian (fail to reject H0)
#
# Anderson-Darling Test:
# At significance level 15.00, data does not look normal (reject H0)
# At significance level 10.00, data does not look normal (reject H0)
# At significance level 5.00, data looks normal (fail to reject H0)
# At significance level 2.50, data looks normal (fail to reject H0)
# At significance level 1.00, data looks normal (fail to reject H0)

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller

def test_stationarity(df, columns):
    for column in columns:
        print(f"\nTesting stationarity for column: {column}")
        
        # Perform ADF test
        result = adfuller(df[column])
        
        print('ADF Statistic:', result[0])
        print('p-value:', result[1])
        print('Critical Values:', result[4])
        
        # Interpretation based on p-value
        if result[1] <= 0.05:
            print(f"The series {column} is likely stationary.")
        else:
            print(f"The series {column} is likely non-stationary.")

# Given your dataframe name is 'df'
columns_to_test = ["ShannonEntropy", "HHI", "Gini", "Nakamoto"]
test_stationarity(df, columns_to_test)
# Out:
# Testing stationarity for column: ShannonEntropy
# ADF Statistic: -0.24790422615040433
# p-value: 0.932565433324567
# Critical Values: {'1%': -3.5443688564814813, '5%': -2.9110731481481484, '10%': -2.5931902777777776}
# The series ShannonEntropy is likely non-stationary.
#
# Testing stationarity for column: HHI
# ADF Statistic: -0.3395329519330737
# p-value: 0.9197156654353872
# Critical Values: {'1%': -3.548493559596539, '5%': -2.912836594776334, '10%': -2.594129155766944}
# The series HHI is likely non-stationary.
#
# Testing stationarity for column: Gini
# ADF Statistic: -6.519218448533989
# p-value: 1.0524113019419314e-08
# Critical Values: {'1%': -3.5443688564814813, '5%': -2.9110731481481484, '10%': -2.5931902777777776}
# The series Gini is likely stationary.
#
# Testing stationarity for column: Nakamoto
# ADF Statistic: -0.04175750987610712
# p-value: 0.9549394911362883
# Critical Values: {'1%': -3.5506699942762414, '5%': -2.913766394626147, '10%': -2.5946240473991997}
# The series Nakamoto is likely non-stationary.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
df=data.copy()
def plot_autocorrelation(df, column_name):
    plt.figure(figsize=(12, 5))
    
    max_lags = len(df) // 2 - 1  # Ensure lags are less than half the sample size
    
    # ACF plot
    plt.subplot(1, 2, 1)
    plot_acf(df[column_name], lags=max_lags, ax=plt.gca())
    plt.title(f'ACF for {column_name}')
    
    # PACF plot
    plt.subplot(1, 2, 2)
    plot_pacf(df[column_name], lags=max_lags, ax=plt.gca())
    plt.title(f'PACF for {column_name}')
    
    plt.tight_layout()

# Save the figure with high resolution
    filename = f"{column_name}_autocorrelation_attester.png"
    plt.savefig(filename, dpi=1800)  # You can adjust the DPI value for desired resolution.
    plt.show()

# For each of your columns
columns_to_test = ["ShannonEntropy", "HHI", "Gini", "Nakamoto"]
for column in columns_to_test:
    plot_autocorrelation(df, column)

# %% [markdown]
# > ACF Plot: The autocorrelation function plot gives you the correlation of the series with itself, lagged by x time units. So the y-axis is the correlation and the x-axis is the number of time units of lag.
#
# > PACF Plot: The partial autocorrelation function plot gives the correlation of the series with itself, lagged by x time units, but with the relationships at shorter lags removed.
#
# **Interpreting these plots**:
#
# > Sudden Drop-Off: If either the ACF or PACF shows a sudden drop-off after a certain number of lags, this might indicate that this is the order of the autoregressive term.
#
# > Gradual Decline: If the ACF shows a gradual decline and PACF shows a sudden drop-off, this might indicate that this is the order of the moving average term.
#
# > Significant Spikes: If there are significant spikes at specific lags, this can indicate seasonality in the data.
#
# By analyzing the ACF and PACF plots, you can get insights about potential patterns in your data and inform your choices when building time series models.

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
import pandas as pd

# Assuming 'data' is your DataFrame
df = data.copy()
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

# Ensure consistent frequency
if pd.infer_freq(df.index) is not None:
    df = df.asfreq(pd.infer_freq(df.index))
else:
    raise ValueError("Data frequency can't be inferred. Ensure your data has consistent frequency or manually set it.")

# Adjust matplotlib settings
plt.rcParams['text.usetex'] = False
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

# Define a function to decompose and plot
def plot_decomposition(df, column_name, period=None):
    decomposition = seasonal_decompose(df[column_name], period=period, model='additive')
    
    plt.figure(figsize=(14, 8))
    
    # Original
    plt.subplot(4, 1, 1)
    plt.plot(df[column_name], label='Original')
    plt.legend(loc='best')
    plt.title(column_name)
    
    # Trend
    plt.subplot(4, 1, 2)
    plt.plot(decomposition.trend, label='Trend')
    plt.legend(loc='best')
    plt.title("Trend")

    # Seasonal
    plt.subplot(4, 1, 3)
    plt.plot(decomposition.seasonal, label='Seasonality')
    plt.legend(loc='best')
    plt.title("Seasonality")

    # Residuals
    plt.subplot(4, 1, 4)
    plt.plot(decomposition.resid, label='Residuals')
    plt.legend(loc='best')
    plt.title("Residuals")
    
    plt.tight_layout()
    
    # Save the figure to PNG
    plt.savefig(f'{column_name}_decomposition_attester.png', dpi=900)
    plt.show()

# Decompose
# Provided code to set date as index, infer frequency, and plot
columns_to_decompose = ["ShannonEntropy", "HHI", "Gini", "Nakamoto"]
for column in columns_to_decompose:
    plot_decomposition(df, column)

# %%
import numpy as np

def detect_seasonality_frequency(ts):
    # Compute the FFT and power spectrum
    fft_vals = np.fft.fft(ts.fillna(0))
    fft_freq = np.fft.fftfreq(len(ts))
    
    # Remove the negative frequencies
    fft_vals = fft_vals[fft_freq > 0]
    fft_freq = fft_freq[fft_freq > 0]
    
    # Find the frequency with the maximum power (excluding the zero frequency)
    dominant_frequency = fft_freq[np.argmax(np.abs(fft_vals)[1:]) + 1]
    
    # Convert frequency to period (seasonality)
    seasonality = int(np.round(1 / dominant_frequency))
    return seasonality

for column in columns_to_decompose:
    seasonality = detect_seasonality_frequency(df[column].dropna())
    print(f"Detected seasonality for {column}: {seasonality} time units")
# Out:
# Detected seasonality for ShannonEntropy: 30 time units
# Detected seasonality for HHI: 30 time units
# Detected seasonality for Gini: 20 time units
# Detected seasonality for Nakamoto: 30 time units

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.linear_model import LinearRegression
import numpy as np

def estimate_growth_rate(df, column_name):
    # Decompose the time series
    decomposition = seasonal_decompose(df[column_name], model='additive')
    
    # Extract trend component
    trend = decomposition.trend.dropna()
    
    # Create a time variable, t
    t = np.arange(len(trend)).reshape(-1, 1)
    
    # Fit linear regression model
    model = LinearRegression().fit(t, trend)
    
    # Return the slope as the growth rate
    return model.coef_[0]

for column in columns_to_decompose:
    growth_rate = estimate_growth_rate(df, column)
    print(f"Estimated growth rate for {column}: {growth_rate:.4f} per time unit")
# Out:
# Estimated growth rate for ShannonEntropy: 624.2607 per time unit
# Estimated growth rate for HHI: -0.0000 per time unit
# Estimated growth rate for Gini: -0.0000 per time unit
# Estimated growth rate for Nakamoto: 310.9704 per time unit

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

df = data.copy()
# Ensure LaTeX is disabled
plt.rcParams['text.usetex'] = False

# Use the 'STIX' fonts for a LaTeX-like appearance without requiring LaTeX
plt.rcParams['font.family'] = 'STIXGeneral'

# Compute the correlation matrix
corr_matrix = df[columns_to_decompose].corr()

# Compute the matrix of p-values
p_matrix = df[columns_to_decompose].corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*corr_matrix.shape)

# Create an array to hold the annotations
annotations = corr_matrix.copy()
for i in range(len(corr_matrix)):
    for j in range(len(corr_matrix)):
        if i != j:
            annotations.iloc[i, j] = f'{corr_matrix.iloc[i, j]:.2f}\n(p={p_matrix.iloc[i, j]:.4f})'
        else:
            annotations.iloc[i, j] = f'{corr_matrix.iloc[i, j]:.2f}'

# Plot the heatmap with the "RdBu_r" colormap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=annotations, cmap="RdBu_r", vmin=-1, vmax=1, square=True, linewidths=.5, fmt='')
plt.title('Correlation Matrix of Variables')

# Add a figure note
figure_note = """
Note: Values in each cell represent the Pearson correlation coefficient between variables, 
with the p-value displayed in parentheses below. A p-value less than 0.05 typically indicates 
that the correlation is statistically significant at the 95% confidence level.
"""
plt.figtext(0.1, -0.01, figure_note, ha="left", va="top", fontsize=10, wrap=True)

plt.tight_layout()
filename = "index_Correlations_attester.png"
plt.savefig(filename, dpi=900)  # saves with 900 DPI.
plt.show()

# %% [markdown]
# # References:
# Code adapted from SoK: Blockchain Decentralization: https://arxiv.org/abs/2205.04256
